# %%
import matplotlib.pyplot as plt
import numpy as np

ordenado = [0.020,0.433,1.729,19.116,115.050]
decrescente = [0.025,0.342,1.254,22.144,120.843]
randons = [0.005,0.030,0.064,21.402,119.745]
repetidos = [0.006,0.057,0.067,21.625,120.580]
tamanho =[100,500,1000,5000,10000]

plt.figure(figsize=(10,6))
plt.plot(tamanho, ordenado,'-r',label='Ordenado')
plt.plot(tamanho, decrescente,'-g', label='Decrescente')
plt.plot(tamanho,randons,'-y',label='Aleatório')
plt.plot(tamanho, repetidos,label='Repetidos')

plt.xlabel('Tamanho das entradas')
plt.ylabel('Tempo de operação(ms)')
plt.title("Comparação de Desempenho do algoritmo para diferentes entradas")
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
tamanho =[100,500,1000,5000,10000]
aord = [0.199,10.47,37.50,1177.1,4997.5]
adec = 0.497,10.47 ,60.94 ,1379.2 ,5752.4
arand = [0.0, 9.375 ,57.25 ,1440.5, 5479.5]
arepet = [0.595, 13.76, 47.07, 1242.4, 5286.8]

bord =[0.199 ,2.294, 3.787, 15.36, 36.48]
bdec =[0.194, 1.599, 3.586, 22.54, 32.71]
brand =[0.199 ,1.395, 2.991, 16.45, 34.61 ]
brepet =[0.299 ,1.594, 3.972, 16.06, 32.99]

cord =[45.61, 187.79 ,392.4 ,1999.0 ,3886.4]
cdec =[39.89, 218.8, 397.8, 2032.3, 4234.9]
crand =[40.17, 194.2, 404.0, 2071.7, 4153.1 ]
crepet =[43.18 ,200.5, 375.5, 2080.7, 4132.3]

dord =[0.0, 1.563, 3.124, 17.277,40.779]
ddec = [0.0 ,1.577, 3.13, 14.105, 41.129]
drand =[0.0, 1.563, 3.16 ,15.738, 37.591]
drepet =[0.0, 1.560, 3.126, 15.698, 31.393]

fig,ax = plt.subplots(2,2,figsize=(10,6))

ax[0,0].plot(tamanho,aord, 'g',label='Ordenado')
ax[0,0].plot(tamanho,adec, 'r',label='Decrescente')
ax[0,0].plot(tamanho,arand,label='Aleatório')
ax[0,0].plot(tamanho,arepet, 'y',label='AleaRepetidos')
ax[0,0].set_title('Alg A')
ax[0,0].grid(True)
ax[0,0].legend(loc='best')
ax[0,0].set_ylabel('Tempo(ms)')
ax[0,0].set_xlabel('Tamanho')

ax[0,1].plot(tamanho,bord, 'g',label='Ordenado')
ax[0,1].plot(tamanho,bdec, 'r',label='Decrescente')
ax[0,1].plot(tamanho,brand,label='Aleatório')
ax[0,1].plot(tamanho,brepet, 'y',label='AleaRepetidos')
ax[0,1].set_title('Alg B')
ax[0,1].grid(True)
ax[0,1].legend(loc='best')
ax[0,1].set_ylabel('Tempo(ms)')
ax[0,1].set_xlabel('Tamanho')


ax[1,0].plot(tamanho,cord, 'g',label='Ordenado')
ax[1,0].plot(tamanho,cdec, 'r',label='Decrescente')
ax[1,0].plot(tamanho,crand,label='Aleatório')
ax[1,0].plot(tamanho,crepet, 'y',label='AleaRepetidos')
ax[1,0].set_title('Alg C')
ax[1,0].grid(True)
ax[1,0].legend(loc='best')
ax[1,0].set_ylabel('Tempo(ms)')
ax[1,0].set_xlabel('Tamanho')

ax[1,1].plot(tamanho,dord, 'g',label='Ordenado')
ax[1,1].plot(tamanho,ddec, 'r',label='Decrescente')
ax[1,1].plot(tamanho,drand,label='Aleatório')
ax[1,1].plot(tamanho,drepet, 'y',label='AleaRepetidos')
ax[1,1].set_title('Alg D')
ax[1,1].grid(True)
ax[1,1].legend(loc='best')
ax[1,1].set_ylabel('Tempo(ms)')
ax[1,1].set_xlabel('Tamanho')
plt.subplots_adjust(top=0.9, bottom=0.1, left=0.1, right=0.9, hspace=0.3, wspace=0.3)


plt.show()
