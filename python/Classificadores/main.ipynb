# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("pankrzysiu/cifar10-python")

print("Path to dataset files:", path)
# Out:
# Downloading to /home/leftlu/.cache/kagglehub/datasets/pankrzysiu/cifar10-python/1.archive...
# 100%|██████████| 325M/325M [00:14<00:00, 22.8MB/s]
# Extracting files...
# Path to dataset files: /home/leftlu/.cache/kagglehub/datasets/pankrzysiu/cifar10-python/versions/1
