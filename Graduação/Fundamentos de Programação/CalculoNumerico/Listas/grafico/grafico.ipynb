# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rload =[1.4767,1.3811, 1.1401,0.9866, 0.7223,0.6652,0.4944,0.4366,0.3806,0.33439,0.29898,0.2395,0.1986,0.1515,0.0707,0.01590,0.00694]
pout =[1.09,1.12,1.19,1.24,1.30,1.32,1.28,1.29,1.24,1.19,1.17,1.06,0.96,0.82,0.49,0.13,0.06]

plt.plot(rload, pout,linestyle='-',marker='o')
plt.grid()
plt.xlabel('Rload')
plt.ylabel('Pout')

plt.show()
